# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
def Ode (x, y):
    return x - y

# %%
Xmin = 0; Xmax = 5
Ymin = 1; Ymax = 4
H = 0.25

# %%
def SlopeField (ode, xmin, xmax, ymin, ymax, h):
    dx = xmax - xmin; m = int (dx / h + 0.5); x = np.linspace (xmin, xmax, m + 1); dx /= m
    dy = ymax - ymin; n = int (dy / h + 0.5); y = np.linspace (ymin, ymax, n + 1); dy /= n
    
    xx, yy = np.meshgrid (x, y)
    mm = ode (xx, yy); uu = 0.9 * h / np.sqrt (1 + mm ** 2); vv = mm * uu
    
    pl.axis ('equal')
    pl.plot (xx, yy, '.', color = 'gray')
    pl.quiver (xx - uu / 2, yy - vv / 2, uu, vv, angles = 'xy', scale_units = 'xy', scale = 1, width = 0.001)

# %%
SlopeField (Ode, Xmin, Xmax, Ymin, Ymax, H)

# %%
SlopeField (lambda x, y: - x / y, -2, 2, -2, 2, 0.25)
# Out:
# C:\Users\jw\AppData\Local\Temp\ipykernel_4728\2563238496.py:1: RuntimeWarning: divide by zero encountered in divide
#   SlopeField (lambda x, y: - x / y, -2, 2, -2, 2, 0.25)
# C:\Users\jw\AppData\Local\Temp\ipykernel_4728\2563238496.py:1: RuntimeWarning: invalid value encountered in divide
#   SlopeField (lambda x, y: - x / y, -2, 2, -2, 2, 0.25)
# C:\Users\jw\AppData\Local\Temp\ipykernel_4728\1877217579.py:6: RuntimeWarning: invalid value encountered in multiply
#   mm = ode (xx, yy); uu = 0.9 * h / np.sqrt (1 + mm ** 2); vv = mm * uu

# %%
SlopeField (lambda x, y: - x / y, -2, 2, -2, 2, 0.3)
